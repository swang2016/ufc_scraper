# %%
import requests
import urllib3
from bs4 import BeautifulSoup
import pandas as pd
import re
from datetime import datetime, timedelta
pd.set_option('display.max_columns', 500)

from ufc_scraper import get_fight_stats, get_fight_card, get_all_fight_stats, get_fighter_details, update_fight_stats, update_fighter_details

# %% [markdown]
# The section below shows how to use the functions for an initial data pull of fight history and fighter stats:

# %%
#scrape data from scratch
fight_hist = get_all_fight_stats(timeout = 10)

fighter_stats = get_fighter_details(fight_hist.fighter_url.unique())
# Out:
# http://ufcstats.com/event-details/6750e338922a099d
# http://ufcstats.com/event-details/899eaba48fa864a6
# http://ufcstats.com/event-details/dba230fe33011201
# http://ufcstats.com/event-details/79ff6545b0abc685
# http://ufcstats.com/event-details/c398235fcaf8d71d
# http://ufcstats.com/event-details/a9df5ae20a97b090
# http://ufcstats.com/event-details/e4a9dbade7c7e1a7
# http://ufcstats.com/event-details/902ab9197b83d0db
# http://ufcstats.com/event-details/dab0e6cb8c932162
# http://ufcstats.com/event-details/eaea0fc7b76525a8
# http://ufcstats.com/event-details/cce79e827569f26e
# http://ufcstats.com/event-details/bd85ca0bb4f26cfc
# http://ufcstats.com/event-details/010986ee359fb863
# http://ufcstats.com/event-details/a8e8587a06e73c87
# http://ufcstats.com/event-details/5ef0088c1b19beeb
# http://ufcstats.com/event-details/53e4e21f4c688801
# http://ufcstats.com/event-details/3feed7d02711d8b7
# http://ufcstats.com/event-details/5a558ba1ff5e9121
# ...

# %%
len(fight_hist)
# Out:
# 15198

# %%
#save data
fight_hist.to_csv('~/Projects/ufc_scraper/data/fight_hist.csv', index = False)
fighter_stats.to_csv('~/Projects/ufc_scraper/data/fighter_stats.csv', index = False)

# %% [markdown]
# The section below shows how to use the function for updating dataframe for fight history and fighter stats:

# %%
#get already saved data
fight_hist_old = pd.read_csv('~/Projects/ufc_scraper/data/fight_hist.csv')

fighter_stats_old = pd.read_csv('~/Projects/ufc_scraper/data/fighter_stats.csv')

# %%
#update fight hist dataframe
fight_hist_updated = update_fight_stats(fight_hist_old)

#update fighter stats
fighter_stats_updated = update_fighter_details(fight_hist_updated.fighter_url.unique(), fighter_stats_old)
# Out:
# http://ufcstats.com/event-details/3f7c14c7eca7195d
# http://ufcstats.com/event-details/a1153013cb5f628f
# http://ufcstats.com/event-details/4304992c2acc187b
# adding new fighter: http://ufcstats.com/fighter-details/4b93a88f3b1de35b
# adding new fighter: http://ufcstats.com/fighter-details/5d1b7e3dd9e11074
# adding new fighter: http://ufcstats.com/fighter-details/8e382b585a92affe

# %%
#save updated dataframes
fight_hist_updated.to_csv('~/Projects/ufc_scraper/data/fight_hist.csv', index = False)
fighter_stats_updated.to_csv('~/Projects/ufc_scraper/data/fighter_stats.csv', index = False)

# %%
fight_hist_updated
# Out:
#                     date                                          fight_url  \
# 0      February 13, 2021  http://ufcstats.com/fight-details/be94e5b7a35c...
# 1      February 13, 2021  http://ufcstats.com/fight-details/be94e5b7a35c...
# 2      February 13, 2021  http://ufcstats.com/fight-details/25b8c932da5e...
# 3      February 13, 2021  http://ufcstats.com/fight-details/25b8c932da5e...
# 4      February 13, 2021  http://ufcstats.com/fight-details/26fbf026beb8...
# ...                  ...                                                ...
# 11907  November 12, 1993  http://ufcstats.com/fight-details/cecdc0da5842...
# 11908  November 12, 1993  http://ufcstats.com/fight-details/2d2bbc86e941...
# 11909  November 12, 1993  http://ufcstats.com/fight-details/2d2bbc86e941...
# 11910  November 12, 1993  http://ufcstats.com/fight-details/567a09fd200c...
# 11911  November 12, 1993  http://ufcstats.com/fight-details/567a09fd200c...
#
# ...
